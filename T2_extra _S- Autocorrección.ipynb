# %% [markdown]
# <h1><center> ¿Cómo procesar palabras para construir un autocorrector? </center></h1>
#
# <b>Maestría</b>: Inteligencia Artificial Aplicada <br>
# <b>Asignatura:</b> Procesamiento Acelerado de Lenguaje Natural <br>
# <b>Profesor:</b> Edwin J. Rueda

# %% [markdown]
# Todos los días usamos autocorrectores: en el celular y el computador. Esta es una función muy útil que nos permite corregir en tiempo de escritura una palabra sin tener que ajustar de forma manual, solo seleccionar la sugerencia correcta. Pero, ¿Cómo funciona un autocorrector?

# %% [markdown]
# <img width="40%" src="data:image/jpeg;base64,..."/>

# %% [markdown]
# Este notebook tiene como proposito implementar un autocorrector siguiendo los pasos:
# - Contar la cantidad de veces que aparece una palabra en un corpus
# - Obtener la probabilidad de la palabra en el corpus
# - Manipular la palabra (eliminar, combinar, reemplazar, insertar) caracteres -> tokens
# - Implementar la distancia mínima para comparar strings.

# %%
import re
from collections import Counter
import numpy as np
import pandas as pd

# %% [markdown]
# ### Carga y preprocesamiento de los datos
#
# Como hemos visto, el primer paso será preprocesar los datos. Para ello, construiremos una función `process_data`, encargada de leer el corpus, convertir todas las palabras a *lowercase* y retornar la lista de palabras.

# %%
from nltk.corpus import cess_esp

sentences = cess_esp.sents()
print(sentences)
# Out:
# [['El', 'grupo', 'estatal', 'Electricité_de_France', '-Fpa-', 'EDF', '-Fpt-', 'anunció', 'hoy', ',', 'jueves', ',', 'la', 'compra', 'del', '51_por_ciento', 'de', 'la', 'empresa', 'mexicana', 'Electricidad_Águila_de_Altamira', '-Fpa-', 'EAA', '-Fpt-', ',', 'creada', 'por', 'el', 'japonés', 'Mitsubishi_Corporation', 'para', 'poner_en_marcha', 'una', 'central', 'de', 'gas', 'de', '495', 'megavatios', '.'], ['Una', 'portavoz', 'de', 'EDF', 'explicó', 'a', 'EFE', 'que', 'el', 'proyecto', 'para', 'la', 'construcción', 'de', 'Altamira_2', ',', 'al', 'norte', 'de', 'Tampico', ',', 'prevé', 'la', 'utilización', 'de', 'gas', 'natural', 'como', 'combustible', 'principal', 'en', 'una', 'central', 'de', 'ciclo', 'combinado', 'que', 'debe', 'empezar', 'a', 'funcionar', 'en', 'mayo_del_2002', '.'], ...]

# %% [markdown]
# ola -> hola -> cola -> aca -> prob. freq

# %%
def process_data():
    words = []
    sentences = cess_esp.sents()
    text = ""
    ### CODE ###
    for line in sentences:
        for word in line:
            text += word.lower() + " "
    return re.findall("\w+",text)

# %%
word_l = process_data()
vocab = set(word_l)  # this will be your new vocabulary
print(f"The first ten words in the text are: \n{word_l[0:10]}")
print(f"There are {len(vocab)} unique words in the vocabulary.")
# Out:
# The first ten words in the text are:
# ['el', 'grupo', 'estatal', 'electricité_de_france', 'fpa', 'edf', 'fpt', 'anunció', 'hoy', 'jueves']
# There are 24137 unique words in the vocabulary.

# %% [markdown]
# Una vez cargado nuestro corpus, el primer paso es contar la cantidad de veces que aparece una misma palabra. Para ello, implementaremos una función `get_count`, la cual retornará un diccionario donde la `key` será cada palabra y el `value` la cantidad de veces que aparece dicha palabra en el corpus:

# %%
def get_count(word_l):
    '''
    Input:
        word_l: a set of words representing the corpus. 
    Output:
        word_count_dict: The wordcount dictionary where key is the word and value is its frequency.
    '''
    word_count_dict = {}  # fill this with word counts
    ### CODE ### 
    for word in word_l:
        if word not in word_count_dict.keys():
            word_count_dict[word] = 1
        else:
            word_count_dict[word] += 1
    return word_count_dict

# %%
#DO NOT MODIFY THIS CELL
word_count_dict = get_count(word_l)
print(f"There are {len(word_count_dict)} key values pairs")
print(f"The count for the word 'casa' is {word_count_dict.get('casa',0)}")
# Out:
# There are 24137 key values pairs
# The count for the word 'casa' is 51

# %%
word_count_dict

# %% [markdown]
# Con el conteo de palabras realizado. Lo siguiente es obtener las probabilidades de cada palabra, las cuales están definidas así:
#
# $$ P(w_i) = \frac{C(w_i)}{M} $$
#
# Donde,
#
# $C(w_i)$ Es el numero de veces que aparece la palabra $w_i$ en el corpus.
#
# $M$ es el total de palabras en el corpus.

# %%
sum(word_count_dict.values())
# Out:
# 171428

# %%
def get_probs(word_count_dict):
    '''
    Input:
        word_count_dict: The wordcount dictionary where key is the word and value is its frequency.
    Output:
        probs: A dictionary where keys are the words and the values are the probability that a word will occur. 
    '''
    probs = {}  # return this variable correctly
    total_w = sum(word_count_dict.values())
    for word in word_count_dict.keys():
        probs[word] = word_count_dict[word]/total_w
    ### CODE ###
    return probs

# %%
#DO NOT MODIFY THIS CELL
probs = get_probs(word_count_dict)
print(f"Length of probs is {len(probs)}")
test_w = "bajo"
print(f"P('{test_w}') is {probs[test_w]:.4f}")
# Out:
# Length of probs is 24137
# P('bajo') is 0.0003

# %%
probs
# Out:
# {'el': 0.03507595025316751,
#  'grupo': 0.0004666682222274074,
#  'estatal': 4.666682222274074e-05,
#  'electricité_de_france': 5.833352777842593e-06,
#  'fpa': 0.004795015983386611,
#  'edf': 2.9166763889212964e-05,
#  'fpt': 0.004789182630608769,
#  'anunció': 0.00022750075833586112,
#  'hoy': 0.0020825069416898056,
#  'jueves': 0.00015166717222390741,
#  'la': 0.04039596798655996,
#  'compra': 0.00012833376111253704,
#  'del': 0.013189210630702101,
#  '51_por_ciento': 1.1666705555685186e-05,
#  'de': 0.06000186667288891,
#  'empresa': 0.00036166787222624076,
#  'mexicana': 4.083346944489815e-05,
#  'electricidad_águila_de_altamira': 5.833352777842593e-06,
#  'eaa': 1.750005833352778e-05,
#  'creada': 3.500011666705556e-05,
#  'por': 0.008995029983433277,
#  'japonés': 9.333364444548149e-05,
#  'mitsubishi_corporation': 5.833352777842593e-06,
#  'para': 0.00769419231397438,
#  'poner_en_marcha': 3.500011666705556e-05,
#  'una': 0.008493361644538814,
#  'central': 0.00015166717222390741,
#  'gas': 8.750029166763889e-05,
#  '495': 1.1666705555685186e-05,
#  'megavatios': 2.333341111137037e-05,
#  'portavoz': 0.0001691672305574352,
#  'explicó': 0.0002566675222250741,
#  'a': 0.017686725622418742,
#  'efe': 0.00030333434444781483,
#  'que': 0.032491774972583244,
#  'proyecto': 0.0002391674638915463,
#  'construcción': 9.916699722332408e-05,
#  'altamira_2': 1.1666705555685186e-05,
#  'al': 0.0059091863639545465,
#  'norte': 7.583358611195371e-05,
#  'tampico': 5.833352777842593e-06,
#  'prevé': 7.583358611195371e-05,
#  'utilización': 4.083346944489815e-05,
#  'natural': 7.000023333411111e-05,
#  'como': 0.004240847469491565,
#  'combustible': 2.333341111137037e-05,
#  'principal': 0.0001633338777795926,
#  'en': 0.027090090300301,
#  'ciclo': 2.9166763889212964e-05,
#  'combinado': 1.750005833352778e-05,
#  'debe': 0.00038500128333761113,
#  'empezar': 2.333341111137037e-05,
#  'funcionar': 5.833352777842593e-06,
#  'mayo_del_2002': 5.833352777842593e-06,
#  'electricidad': 4.083346944489815e-05,
#  'producida': 1.750005833352778e-05,
#  'pasará': 1.750005833352778e-05,
#  'red': 8.16669388897963e-05,
#  'eléctrica': 9.916699722332408e-05,
#  'pública': 0.00013416711389037964,
#  'méxico': 0.00018083393611312038,
#  'en_virtud_de': 1.750005833352778e-05,
#  'un': 0.010896702989009964,
#  'acuerdo': 0.0003966679888932963,
#  'venta': 0.00012250040833469445,
#  'energía': 8.16669388897963e-05,
#  'con': 0.009117530391767973,
#  'comisión_federal_de_electricidad': 5.833352777842593e-06,
#  'cfe': 1.750005833352778e-05,
#  'duración': 4.666682222274074e-05,
#  '25': 0.00011666705555685186,
#  'años': 0.0016975056583521946,
#  'no': 0.007904193013976712,
#  'quiso': 7.583358611195371e-05,
#  'revelar': 5.833352777842593e-06,
#  'cuánto': 1.1666705555685186e-05,
#  '0': 0.023006743355811186,
#  'pagó': 1.750005833352778e-05,
#  'su': 0.007711692372307908,
#  'participación': 0.00012250040833469445,
#  'mayoritaria': 5.833352777842593e-06,
#  'intervendrá': 5.833352777842593e-06,
#  'asistente': 5.833352777842593e-06,
#  'y': 0.025369251230837435,
#  'posteriormente': 4.666682222274074e-05,
#  'se': 0.011357537858459528,
#  'encargará': 2.333341111137037e-05,
#  'explotarla': 5.833352777842593e-06,
#  'accionista': 1.750005833352778e-05,
#  'mitsubishi': 5.833352777842593e-06,
#  'participaron': 5.833352777842593e-05,
#  '1998': 0.00011083370277900926,
#  'licitación': 1.750005833352778e-05,
#  'licencias': 7.583358611195371e-05,
#  'construir': 1.750005833352778e-05,
#  'centrales': 3.500011666705556e-05,
#  'eléctricas': 3.500011666705556e-05,
#  'quedaron': 4.666682222274074e-05,
#  'dos': 0.0018258394194647315,
#  'cada': 0.0007116690388967963,
#  'río_bravo': 1.1666705555685186e-05,
#  'saltillo': 1.750005833352778e-05,
#  'compañía': 0.00022166740555801853,
#  'francesa': 9.916699722332408e-05,
#  'altamira': 5.833352777842593e-06,
#  'tuxpán': 5.833352777842593e-06,
#  'japonesa': 7.000023333411111e-05,
#  'tiene': 0.0009916699722332407,
#  'previsto': 9.333364444548149e-05,
#  'invertir': 3.500011666705556e-05,
#  '194': 5.833352777842593e-06,
#  'millones': 0.0011375037916793057,
#  'euros': 0.00020416734722449075,
#  '186': 5.833352777842593e-06,
#  'dólares': 0.0005541685138950463,
#  'potencia': 5.833352777842593e-05,
#  '134': 5.833352777842593e-06,
#  '28': 9.916699722332408e-05,
#  'primera': 0.0006941689805632685,
#  'funcionará': 5.833352777842593e-06,
#  'cuya': 0.00019833399444664816,
#  'prevista': 4.083346944489815e-05,
#  'es': 0.0056700189000630005,
#  '247': 5.833352777842593e-06,
#  'alcaldesa': 1.750005833352778e-05,
#  'málaga': 5.833352777842593e-05,
#  'cabeza': 0.0001633338777795926,
#  'lista': 0.00012250040833469445,
#  'pp': 0.000344167813892713,
#  'congreso': 0.00019833399444664816,
#  'esta': 0.0014291714305714352,
#  'provincia': 5.833352777842593e-05,
#  'celia_villalobos': 5.833352777842593e-06,
#  'pidió': 0.00012833376111253704,
#  'los': 0.01860256200854003,
#  'militantes': 6.416688055626852e-05,
#  'formación': 0.00021583405278017593,
#  'sepan': 1.750005833352778e-05,
#  'administrar': 5.833352777842593e-06,
#  'victoria': 0.0003091676972256574,
#  'porque': 0.0013416711389037962,
#  'vale': 3.500011666705556e-05,
#  'revancha': 5.833352777842593e-05,
#  'insulto': 1.1666705555685186e-05,
#  'o': 0.002578341927806426,
#  'ataque': 0.00015166717222390741,
#  'eso': 0.0005716685722285741,
#  'ellos': 0.0004900016333387778,
#  'intervención': 7.000023333411111e-05,
#  'ante': 0.0009975033250110834,
#  'populares': 4.666682222274074e-05,
#  'hotel': 3.500011666705556e-05,
#  'capital': 0.0003091676972256574,
#  'malagueña': 1.1666705555685186e-05,
#  'elegido': 6.416688055626852e-05,
#  'sede': 0.00012250040833469445,
#  'noche': 0.00015750052500175,
#  'electoral': 0.00028000093333644446,
#  'villalobos': 1.750005833352778e-05,
#  'dio': 0.00015166717222390741,
#  'las': 0.011217537391791306,
#  'gracias': 2.9166763889212964e-05,
#  'muchos': 0.00030333434444781483,
#  'tienen': 0.00044916816389387965,
#  'emoción': 1.750005833352778e-05,
#  'especial': 0.00011666705555685186,
#  'confesó': 2.9166763889212964e-05,
#  'también': 0.0016800056000186667,
#  'especialmente': 0.0001633338777795926,
#  'emocionada': 5.833352777842593e-06,
#  'sus': 0.0029283430944769817,
#  'quintas': 5.833352777842593e-06,
#  'elecciones': 0.0004141680472268241,
#  'generales': 0.00014000046666822223,
#  'diputada': 2.9166763889212964e-05,
#  'electa': 5.833352777842593e-06,
#  'transmitió': 1.1666705555685186e-05,
#  'abrazo': 5.833352777842593e-06,
#  'mi': 0.0004025013416711389,
#  'cariño': 1.750005833352778e-05,
#  'josé_maría_aznar': 9.333364444548149e-05,
#  'quien': 0.0007466691555638519,
#  'definió': 1.1666705555685186e-05,
#  'hombre': 0.0004083346944489815,
#  'ha': 0.004194180647268824,
#  'sabido': 5.2500175000583336e-05,
#  'llevar': 0.00011666705555685186,
#  'hasta': 0.001376671255570852,
#  'gente': 0.00020416734722449075,
#  'ilusionar': 5.833352777842593e-06,
#  'convencer': 2.9166763889212964e-05,
#  'apuesten': 5.833352777842593e-06,
#  'este': 0.001919173063910213,
#  'partido': 0.0008750029166763889,
#  'todas': 0.0004841682805609352,
#  'estas': 0.0004025013416711389,
#  'personas': 0.0005541685138950463,
#  'vamos': 0.00013416711389037964,
#  'defraudar': 5.833352777842593e-06,
#  'aseguró': 0.0004025013416711389,
#  'subrayó': 0.00014583381944606482,
#  'aznar': 0.00012833376111253704,
#  'seguirá': 2.333341111137037e-05,
#  'gobernando': 5.833352777842593e-06,
#  'desde': 0.0013533378444594815,
#  'diálogo': 0.00010500035000116667,
#  'sin': 0.0011666705555685186,
#  'prepotencia': 1.750005833352778e-05,
#  'honradez': 1.750005833352778e-05,
#  'preocupado': 2.9166763889212964e-05,
#  'problemas': 0.0002333341111137037,
#  'seguiremos': 1.1666705555685186e-05,
#  'siendo': 0.00015750052500175,
#  'mismos': 7.583358611195371e-05,
#  'destacó': 0.0002566675222250741,
#  'por_fin': 1.750005833352778e-05,
#  'ganado': 0.00014583381944606482,
#  'circunscripción': 1.1666705555685186e-05,
#  'tanto': 0.00047250157500525,
#  'autonómicas': 1.750005833352778e-05,
#  'senado': 8.16669388897963e-05,
#  'hecho': 0.00043750145833819446,
#  'achacó': 1.750005833352778e-05,
#  'entre': 0.001995006650022167,
#  'otros': 0.0008225027416758055,
#  'factores': 4.666682222274074e-05,
#  'trabajo': 0.0004258347527825093,
#  'alcaldes': 1.1666705555685186e-05,
#  'dando': 5.2500175000583336e-05,
#  'ejemplo': 9.916699722332408e-05,
#  'respecto_al': 4.083346944489815e-05,
#  'resultado': 0.0002450008166693889,
#  'señaló': 0.00035583451944839816,
#  'demuestra': 4.666682222274074e-05,
#  'andalucía': 5.833352777842593e-05,
#  'propiedad': 8.16669388897963e-05,
#  'psoe': 0.0003208344027813426,
#  'andaluces': 2.333341111137037e-05,
#  'parte': 0.000600835336117787,
#  'número': 0.0003908346361154537,
#  '2': 0.000600835336117787,
#  'congreso_por_málaga': 5.833352777842593e-06,
#  'manuel_atencia': 5.833352777842593e-06,
#  'tuvo': 0.00028000093333644446,
#  'recuerdo': 8.750029166763889e-05,
#  'todos': 0.0008458361527871759,
#  'durante': 0.0008633362111207037,
#  'han': 0.0015866719555731853,
#  'anhelado': 5.833352777842593e-06,
#  'importante': 0.00030333434444781483,
#  'habéis': 5.833352777842593e-06,
#  'posible': 0.00037916793055976853,
#  'mayoritario': 2.9166763889212964e-05,
#  'gobierno': 0.0012950043166810555,
#  'atencia': 5.833352777842593e-06,
#  'calificó': 5.2500175000583336e-05,
#  'históricos': 1.750005833352778e-05,
#  'resultados': 0.00017500058333527779,
#  'triple': 1.1666705555685186e-05,
#  'parlamento': 0.00018666728889096297,
#  'andaluz': 6.416688055626852e-05,
#  'ofreció': 9.333364444548149e-05,
#  'comisión_europea': 5.833352777842593e-05,
#  'martes': 0.00011083370277900926,
#  'recibido': 7.583358611195371e-05,
#  'notificación': 5.833352777842593e-06,
#  'concentración': 4.083346944489815e-05,
#  'cual': 0.00021000070000233334,
#  'stet_international_netherlands': 1.1666705555685186e-05,
#  'endesa_telecomunicaciones': 1.1666705555685186e-05,
#  'et': 2.333341111137037e-05,
#  'unión_fenosa_inversiones': 1.1666705555685186e-05,
#  'ufinsa': 2.333341111137037e-05,
#  'adquieren': 1.750005833352778e-05,
#  'control': 0.00015166717222390741,
#  'común': 0.00015166717222390741,
#  'varias': 0.00014583381944606482,
#  'empresas': 0.00037916793055976853,
#  'españolas': 0.00011666705555685186,
#  'cable': 4.083346944489815e-05,
#  'mediante': 0.00014000046666822223,
#  'operación': 0.00030333434444781483,
#  'en_común': 1.1666705555685186e-05,
#  'aragón_de_cable': 1.1666705555685186e-05,
#  'cablelteca': 1.1666705555685186e-05,
#  'supercable_andalucía': 1.1666705555685186e-05,
#  'supercable_sevilla': 1.1666705555685186e-05,
#  'supercable_almería': 1.1666705555685186e-05,
#  'contrato': 7.583358611195371e-05,
#  'gestión': 9.333364444548149e-05,
#  'transferencia': 0.00011083370277900926,
#  'acciones': 0.0001691672305574352,
#  'auna': 1.1666705555685186e-05,
#  'sociedad': 0.00020416734722449075,
#  'holding': 1.1666705555685186e-05,
#  'fin': 0.00019833399444664816,
#  'pertenece': 4.083346944489815e-05,
#  'italiano': 7.583358611195371e-05,
#  'telecom_italia': 5.833352777842593e-06,
#  'presta': 1.750005833352778e-05,
#  'servicios': 0.00019833399444664816,
#  'telecomunicaciones': 9.916699722332408e-05,
#  'español': 0.0003966679888932963,
#  'endesa': 6.416688055626852e-05,
#  'ofrece': 6.416688055626852e-05,
#  'españa': 0.000600835336117787,
#  'unión_fenosa': 5.833352777842593e-06,
#  'asesoría': 1.1666705555685186e-05,
#  'ingeniería': 1.750005833352778e-05,
#  'industria': 0.00011083370277900926,
#  'explotación': 2.333341111137037e-05,
#  'minas': 0.00022166740555801853,
#  'e': 0.0007058356861189537,
#  'inmobiliaria': 1.750005833352778e-05,
#  'son': 0.0013825046083486944,
#  'ofrecen': 1.1666705555685186e-05,
#  'aragón': 1.750005833352778e-05,
#  'islas_canarias': 5.833352777842593e-06,
#  'sevilla': 0.00014000046666822223,
#  'almería': 5.833352777842593e-06,
#  'respectivamente': 6.416688055626852e-05,
#  'nueva': 0.00037916793055976853,
#  'cinco': 0.0004958349861166203,
#  'tras': 0.0007933359777865926,
#  'examen': 1.750005833352778e-05,
#  'preliminar': 2.333341111137037e-05,
#  'documentación': 2.9166763889212964e-05,
#  'presentada': 2.333341111137037e-05,
#  'competencia': 0.00014000046666822223,
#  'estiman': 1.1666705555685186e-05,
#  'podría': 0.0002508341694472315,
#  'entrar': 7.583358611195371e-05,
#  'dentro': 0.00022750075833586112,
#  'campo': 0.00029166763889212964,
#  'aplicación': 6.416688055626852e-05,
#  'reglamentación': 5.833352777842593e-06,
#  'comunitaria': 2.333341111137037e-05,
#  'sobre': 0.0018433394777982593,
#  'concentraciones': 1.1666705555685186e-05,
#  'invita': 1.1666705555685186e-05,
#  'terceras': 1.1666705555685186e-05,
#  'partes': 0.00011083370277900926,
#  'interesadas': 5.833352777842593e-06,
#  'trasmitirle': 5.833352777842593e-06,
#  'observaciones': 1.750005833352778e-05,
#  'plazo': 0.00018083393611312038,
#  'diez': 0.00022750075833586112,
#  'días': 0.000600835336117787,
#  'brasil': 0.00028000093333644446,
#  'buscará': 2.333341111137037e-05,
#  'a_partir_de': 0.00018083393611312038,
#  'mañana': 0.00035583451944839816,
#  'viernes': 0.00014583381944606482,
#  'pase': 2.333341111137037e-05,
#  'final': 0.00043166810556035187,
#  'copa_davis': 1.1666705555685186e-05,
#  'vigentes': 1.750005833352778e-05,
#  'campeones': 3.500011666705556e-05,
#  'australianos': 1.750005833352778e-05,
#  'incómoda': 5.833352777842593e-06,
#  'hierba': 3.500011666705556e-05,
#  'anz_stadium_de_brisbane': 5.833352777842593e-06,
#  'australia': 6.416688055626852e-05,
#  'actual': 0.00021000070000233334,
#  'campeona': 4.666682222274074e-05,
#  'torneo': 0.00012833376111253704,
#  'intentará': 2.333341111137037e-05,
#  'aprovechar': 4.083346944489815e-05,
#  'teórica': 1.750005833352778e-05,
#  'ventaja': 0.0001633338777795926,
#  'luchadores': 5.833352777842593e-06,
#  'jugadores': 0.0003208344027813426,
#  'brasileños': 2.9166763889212964e-05,
#  'salvo': 5.833352777842593e-05,
#  'todoterreno': 1.750005833352778e-05,
#  'gustavo_kuerten': 5.833352777842593e-06,
#  'adaptan': 5.833352777842593e-06,
#  'bien': 0.000501668338894463,
#  'capitán': 4.666682222274074e-05,
#  'australiano': 3.500011666705556e-05,
#  'john_newcombe': 5.833352777842593e-06,
#  'podrá': 0.00011666705555685186,
#  'contar': 6.416688055626852e-05,
#  'uno': 0.0008516695055650186,
#  'mejores': 0.00012250040833469445,
#  'hombres': 0.00028583428611428705,
#  'mark_philippoussis': 1.1666705555685186e-05,
#  'pero': 0.002940009800032667,
#  'lleyton_hewitt': 1.1666705555685186e-05,
#  'pletórico': 5.833352777842593e-06,
#  'patrick_rafter': 5.833352777842593e-06,
#  'viene': 0.00012250040833469445,
#  'ganar': 0.0002566675222250741,
#  'den_bosch': 5.833352777842593e-06,
#  'ser': 0.0013183377277924259,
#  'finalista': 2.333341111137037e-05,
#  'wimbledon': 1.1666705555685186e-05,
#  'aseguran': 4.083346944489815e-05,
#  'gran': 0.000600835336117787,
#  'rendimiento': 1.750005833352778e-05,
#  'equipo': 0.0008458361527871759,
#  'brasileño': 8.750029166763889e-05,
#  'ricardo_acioly': 5.833352777842593e-06,
#  'vuelto': 2.9166763889212964e-05,
#  'confiar': 5.833352777842593e-06,
#  'kuerten': 2.9166763889212964e-05,
#  'fernando_meligeni': 5.833352777842593e-06,
#  'enfrentarse': 7.000023333411111e-05,
#  'aussie': 5.833352777842593e-06,
#  'doble': 8.750029166763889e-05,
#  'enfrentará': 2.333341111137037e-05,
#  'pareja': 2.9166763889212964e-05,
#  'sandon_stolle': 5.833352777842593e-06,
#  'mark_woodforde': 5.833352777842593e-06,
#  'será': 0.0004841682805609352,
#  'formado': 1.750005833352778e-05,
#  'guga': 3.500011666705556e-05,
#  'jaime_oncins': 5.833352777842593e-06,
#  'sorteo': 1.1666705555685186e-05,
#  'deparado': 5.833352777842593e-06,
#  'números': 1.750005833352778e-05,
#  'rafter': 5.833352777842593e-06,
#  'abran': 5.833352777842593e-06,
#  'fuego': 7.583358611195371e-05,
#  'jornada': 0.0002333341111137037,
#  'mientras_que': 0.00035000116667055557,
#  'hewitt': 5.833352777842593e-06,
#  'medirá': 5.833352777842593e-06,
#  'meligeni': 5.833352777842593e-06,
#  'otra': 0.0005658352194507315,
#  'semifinal': 2.333341111137037e-05,
#  'estados_unidos': 0.0003150010500035,
#  'santander': 2.9166763889212964e-05,
#  'tierra': 0.00020416734722449075,
#  'batida': 1.750005833352778e-05,
#  '21': 9.333364444548149e-05,
#  '23_de_julio': 5.833352777842593e-06,
#  'semana': 0.0003091676972256574,
#  'disputarán': 1.750005833352778e-05,
#  'tres': 0.0007816692722309074,
#  'eliminatorias': 3.500011666705556e-05,
#  'permanencia': 5.2500175000583336e-05,
#  'grupo_mundial': 5.833352777842593e-06,
#  'gran_bretaña': 4.666682222274074e-05,
#  'tim_henman': 1.1666705555685186e-05,
#  'greg_rusedski': 5.833352777842593e-06,
#  'jóvenes': 0.00012250040833469445,
#  'arvind_parmar': 5.833352777842593e-06,
#  'barry_cowan': 5.833352777842593e-06,
#  'seguir': 0.00015166717222390741,
#  'temporada': 0.00026833422778075927,
#  'más': 0.0038733462444874816,
#  'elite': 1.1666705555685186e-05,
#  'tenis': 6.416688055626852e-05,
#  'mundial': 0.00022166740555801853,
#  'frente': 0.00011666705555685186,
#  'ecuador': 0.0001691672305574352,
#  'encabezada': 1.1666705555685186e-05,
#  'nicolás_lapentti': 5.833352777842593e-06,
#  'otras': 0.0005075016916723055,
#  'enfrentarán': 1.750005833352778e-05,
#  'zimbabue': 1.1666705555685186e-05,
#  'rumanía': 3.500011666705556e-05,
#  'uzbekistán': 5.833352777842593e-06,
#  'holanda': 2.333341111137037e-05,
#  'taskent': 5.833352777842593e-06,
#  'guillermo_de_la_torre': 5.833352777842593e-06,
#  'entrenador': 0.00011666705555685186,
#  'atleta': 4.666682222274074e-05,
#  'cubano': 9.333364444548149e-05,
#  'javier_sotomayor': 1.1666705555685186e-05,
#  'plusmarquista': 1.1666705555685186e-05,
#  'altura': 7.000023333411111e-05,
#  'está': 0.001289170963903213,
#  'condiciones': 0.0001691672305574352,
#  'medalla': 7.583358611195371e-05,
#  'oro': 0.00012250040833469445,
#  'juegos_de_sydney': 1.1666705555685186e-05,
#  'pese_al': 3.500011666705556e-05,
#  'año': 0.0009216697388991297,
#  'estado': 0.0007058356861189537,
#  'suspendido': 1.750005833352778e-05,
#  'dopaje': 1.1666705555685186e-05,
#  'muy': 0.001172503908346361,
#  'pocas': 8.16669388897963e-05,
#  'competiciones': 4.666682222274074e-05,
#  'iaaf': 1.750005833352778e-05,
#  'tomó': 3.500011666705556e-05,
#  'cómputo': 3.500011666705556e-05,
#  'zona': 0.00022750075833586112,
#  'logró': 0.00012833376111253704,
#  'fuenlabrada': 5.833352777842593e-06,
#  'leganés': 1.750005833352778e-05,
#  'getafe': 1.750005833352778e-05,
#  'municipio': 2.9166763889212964e-05,
#  'escaso': 1.750005833352778e-05,
#  'margen': 3.500011666705556e-05,
#  'mientras': 0.00035583451944839816,
#  'ganó': 6.416688055626852e-05,
#  'alcorcón': 5.833352777842593e-06,
#  'móstoles': 5.833352777842593e-06,
#  'pinto': 5.833352777842593e-06,
#  'municipios': 1.1666705555685186e-05,
#  'forman_parte': 2.9166763889212964e-05,
#  'área': 8.16669388897963e-05,
#  'exterior': 0.00011666705555685186,
#  'humanes': 5.833352777842593e-06,
#  'valdemoro': 5.833352777842593e-06,
#  'congreso_de_los_diputados': 2.9166763889212964e-05,
#  'oeste': 5.2500175000583336e-05,
#  'tradicional': 4.666682222274074e-05,
#  'feudo': 2.333341111137037e-05,
#  'popular': 9.916699722332408e-05,
#  'logro': 2.9166763889212964e-05,
#  'amplias': 1.750005833352778e-05,
#  'mayorías': 1.1666705555685186e-05,
#  'así': 0.00044916816389387965,
#  'majadahonda': 1.1666705555685186e-05,
#  'pozuelo': 5.833352777842593e-06,
#  'triplicaron': 1.1666705555685186e-05,
#  'similares': 7.583358611195371e-05,
#  'obtuvieron': 1.1666705555685186e-05,
#  'algunas': 0.00021000070000233334,
#  'san_sebastián_de_los_reyes': 5.833352777842593e-06,
#  'lograron': 2.333341111137037e-05,
#  '71_por_ciento': 1.1666705555685186e-05,
#  'coslada': 5.833352777842593e-06,
#  '72_por_ciento': 1.750005833352778e-05,
#  'pequeños': 0.00011083370277900926,
#  'pueblos': 4.083346944489815e-05,
#  'voto': 8.750029166763889e-05,
#  'la_hiruela': 5.833352777842593e-06,
#  'pequeño': 0.00010500035000116667,
#  'electores': 4.083346944489815e-05,
#  'cuales': 0.00013416711389037964,
#  '63_por_ciento': 5.833352777842593e-06,
#  'la_acebeda': 5.833352777842593e-06,
#  '90_por_ciento': 1.1666705555685186e-05,
#  '56': 1.750005833352778e-05,
#  'votó': 1.1666705555685186e-05,
#  'campo_real': 5.833352777842593e-06,
#  'ubicará': 5.833352777842593e-06,
#  'futuro': 0.00028000093333644446,
#  'aeropuerto': 3.500011666705556e-05,
#  '60_por_ciento': 2.9166763889212964e-05,
#  'propuestas': 4.666682222274074e-05,
#  'rusia': 0.0001691672305574352,
#  'llegó': 0.00021583405278017593,
#  'conclusión': 3.500011666705556e-05,
#  'hay': 0.0009625032083440278,
#  'conclusiones': 4.083346944489815e-05,
#  'definitivas': 1.750005833352778e-05,
#  'naufragio': 3.500011666705556e-05,
#  'submarino': 6.416688055626852e-05,
#  'nuclear': 7.000023333411111e-05,
#  'kursk': 5.833352777842593e-05,
#  'aferró': 5.833352777842593e-06,
#  'pruebas': 0.00012250040833469445,
#  'tesis': 1.750005833352778e-05,
#  'colisión': 3.500011666705556e-05,
#  'otro': 0.0007641692138973796,
#  'autoridades': 0.00030333434444781483,
#  'rusas': 1.750005833352778e-05,
#  'intentar': 8.16669388897963e-05,
#  'rescate': 3.500011666705556e-05,
#  'secretismo': 1.1666705555685186e-05,
#  'inicial': 2.333341111137037e-05,
#  'moscú': 8.16669388897963e-05,
#  'proclamó': 5.833352777842593e-06,
#  'británico': 7.583358611195371e-05,
#  'norteamericano': 5.833352777842593e-05,
#  'chocó': 5.833352777842593e-06,
#  'londres': 5.2500175000583336e-05,
#  'washington': 8.16669388897963e-05,
#  'rechazaron': 1.750005833352778e-05,
#  'tal': 0.00015166717222390741,
#  'posibilidad': 0.00019833399444664816,
#  'declararon': 1.1666705555685186e-05,
#  'datos': 0.00014583381944606482,
#  'recogidos': 5.833352777842593e-06,
#  'sismógrafos': 1.1666705555685186e-05,
#  'sensores': 1.750005833352778e-05,
#  'hubo': 0.00014000046666822223,
#  'explosiones': 2.333341111137037e-05,
#  'a_bordo': 2.9166763889212964e-05,
#  'joya': 5.833352777842593e-06,
#  'de_acuerdo_con': 8.16669388897963e-05,
#  'registros': 1.1666705555685186e-05,
#  'noruegos': 5.833352777842593e-06,
#  'consecutivas': 1.750005833352778e-05,
#  'echaron': 5.833352777842593e-06,
#  'a_pique': 5.833352777842593e-06,
#  'causar': 2.333341111137037e-05,
#  'graves': 4.083346944489815e-05,
#  'destrozos': 1.1666705555685186e-05,
#  'proa': 1.1666705555685186e-05,
#  'ninguno': 8.16669388897963e-05,
#  'sobrevivió': 5.833352777842593e-06,
#  'próxima': 8.750029166763889e-05,
#  'comienzo': 3.500011666705556e-05,
#  'rescatar': 1.1666705555685186e-05,
#  'cadáveres': 4.666682222274074e-05,
#  'línea': 0.00011083370277900926,
#  'avanzada': 1.1666705555685186e-05,
#  'tiempo': 0.0006591688638962129,
#  'fracaso': 2.333341111137037e-05,
#  'manifestó': 0.00011083370277900926,
#  'puedo': 7.583358611195371e-05,
#  'garantizar': 5.833352777842593e-05,
#  'cien_por_cien': 1.1666705555685186e-05,
#  'declaró': 0.0001691672305574352,
#  'conocería': 5.833352777842593e-06,
#  'causa': 8.750029166763889e-05,
#  'atribuida': 5.833352777842593e-06,
#  'principio': 0.00014000046666822223,
#  'factor': 4.666682222274074e-05,
#  'externo': 2.9166763889212964e-05,
#  'en_concreto': 2.333341111137037e-05,
#  'almirante': 1.750005833352778e-05,
#  'vladímir_kuroyédov': 1.1666705555685186e-05,
#  'comandante': 1.750005833352778e-05,
#  'antes': 0.0006416688055626852,
#  'era': 0.0009100030333434445,
#  'probable': 4.083346944489815e-05,
#  'analizaba': 5.833352777842593e-06,
#  'trece': 4.666682222274074e-05,
#  'posibilidades': 9.333364444548149e-05,
#  'avanzadas': 1.1666705555685186e-05,
#  'estos': 0.0005658352194507315,
#  'incluían': 5.833352777842593e-06,
#  'accidente': 8.16669388897963e-05,
#  'fortuito': 5.833352777842593e-06,
#  'negligencia': 1.1666705555685186e-05,
#  'día': 0.0004958349861166203,
#  'atribuyeron': 5.833352777842593e-06,
#  'recuperarse': 5.833352777842593e-06,
#  '20': 0.00018666728889096297,
#  '30_por_ciento': 4.666682222274074e-05,
#  'cuerpos': 2.333341111137037e-05,
#  'mostró': 0.0001633338777795926,
#  'contrario': 6.416688055626852e-05,
#  'abogó': 3.500011666705556e-05,
#  'más_bien': 1.750005833352778e-05,
#  'intento': 3.500011666705556e-05,
#  'izar': 5.833352777842593e-06,
#  'entero': 3.500011666705556e-05,
#  'puesto_que': 9.333364444548149e-05,
#  'dios': 9.916699722332408e-05,
#  'destino': 6.416688055626852e-05,
#  'naturaleza': 0.00019250064166880556,
#  'decidido': 0.00012833376111253704,
#  'suerte': 8.750029166763889e-05,
#  'esos': 0.0002566675222250741,
#  'blasfemia': 1.1666705555685186e-05,
#  'adelante': 7.583358611195371e-05,
#  'kuroyédov': 5.833352777842593e-06,
#  'al_menos': 0.00011666705555685186,
#  '78': 4.666682222274074e-05,
#  'familiares': 4.666682222274074e-05,
#  'petición': 9.916699722332408e-05,
#  'oficial': 0.00022166740555801853,
#  'subir': 5.2500175000583336e-05,
#  'junto_con': 9.916699722332408e-05,
#  'momento': 0.00037333457778192594,
#  'plataforma': 1.1666705555685186e-05,
#  'semisumergible': 5.833352777842593e-06,
#  'regalia': 5.833352777842593e-06,
#  'navega': 5.833352777842593e-06,
#  'pasado_día_9': 5.833352777842593e-06,
#  'en_dirección_al': 5.833352777842593e-06,
#  'iniciar': 4.666682222274074e-05,
#  '20_de_octubre': 5.833352777842593e-06,
#  'decenio': 5.833352777842593e-06,
#  'cumbres': 1.1666705555685186e-05,
#  'iberoamericanas': 5.833352777842593e-06,
#  'termina': 2.333341111137037e-05,
#  'panamá': 0.00015166717222390741,
#  'servido': 1.750005833352778e-05,
#  'lograr': 0.00012833376111253704,
#  'compromisos': 6.416688055626852e-05,
#  'gubernamentales': 2.9166763889212964e-05,
#  'llevar_a_cabo': 7.583358611195371e-05,
#  'sociales': 0.00012833376111253704,
#  'promover': 3.500011666705556e-05,
#  'intereses': 0.00014000046666822223,
#  'financieros': 4.083346944489815e-05,
#  'resumen': 1.750005833352778e-05,
#  'nueve': 0.00011666705555685186,
#  'declaraciones': 0.00018666728889096297,
#  'suscritas': 5.833352777842593e-06,
#  'jefes': 3.500011666705556e-05,
#  'países': 0.0006416688055626852,
#  'iberoamericanos': 1.750005833352778e-05,
#  'i_cumbre': 5.833352777842593e-06,
#  'guadalajara': 2.333341111137037e-05,
#  '1991': 4.666682222274074e-05,
#  'la_declaración_de_guadalajara': 5.833352777842593e-06,
#  'destaca': 7.000023333411111e-05,
#  ...}

# %% [markdown]
# Hasta aquí, hemos construído un diccionario de probabilidades `probs` el cual contiene que tan probable es que aparezca una determinada palabra en el corpus. Ahora, necesitamos manipular el string para poder encontrar la palabra correcta (sin errores ortográficos).
#
# - **delete_letter**: dada una palabra, retornamos todas las posibles palabras después de remover un caracter. -> `thola -> [hola, tola, thla, thol]`
# - **switch_letter**: dada una palabra, retornamos todas las posibles palabras generadas al combinar dos caracteres adyacentes. `acma -> [cama, amca, acam]`
# - **replace_letter**: dada una palabra, retornamos todas las posibles palabras después de reemplazar un caracter: `doma -> [aoma, boma, coma ..... domz]`
# - **insert_letter**: dada una palabra, retornamos todas las posibles palabras generadas después de añadir un caracter: `oma -> [aoma, boma, coma, ...., omaz]`

# %% [markdown]
# Implementación de la función `delete_letter`:
#
# Dada una palabra, por ejemplo "hola", debe retorna el conjunto: {"ola", "hla", "hol", "hoa"}
#
# Una forma sencilla de hacerlos es dividir la palabra de izquierda a derecha, por ejemplo: `[('', 'hola'), ('h', 'ola'), ('ho', 'la'), ('hol', 'a'), ('hola', '')]`. Una vez definidos estos pares, lo que podemos hacer es tomar la secuencia de caracteres de la izquierda de una tupa, y de la derecha de la otra tupla y así obtendremos: `["ola", "hla", "hoa", "hol"]`

# %%
def delete_letter(word, verbose=False):
    '''
    Input:
        word: the string/word for which you will generate all possible words 
                in the vocabulary which have 1 missing character
    Output:
        delete_l: a list of all possible strings obtained by deleting 1 character from word
    '''
    
    delete_l = []
    split_l = []
    for idx in range(len(word)+1):
        split_l.append((word[:idx], word[idx:]))
    
    for l,r in split_l:
        if r:
            delete_l.append(l + r[1:])
    return  delete_l

# %%
delete_word_l = delete_letter(word="tcoma",
                        verbose=True)
print(delete_word_l)
# Out:
# l, r: [('', 'tcoma'), ('t', 'coma'), ('tc', 'oma'), ('tco', 'ma'), ('tcom', 'a'), ('tcoma', '')]
# ['coma', 'toma', 'tcma', 'tcoa', 'tcom']

# %% [markdown]
# Implementación de la función `switch_letter`:
#
# Dada una palabra, por ejemplo "hola", debe retorna el conjunto: {"ohla", "hloa", "hoal"}
#
# Una forma sencilla de hacerlos es dividir la palabra de izquierda a derecha, por ejemplo: `[('', 'hola'), ('h', 'ola'), ('ho', 'la'), ('hol', 'a'), ('hola', '')]`. Luego, tomar la parte izquierda y concatenar con los dos caracteres primeros de la parte derecha.

# %%
def switch_letter(word, verbose=False):
    '''
    Input:
        word: input string
     Output:
        switches: a list of all possible strings with one adjacent charater switched
    ''' 
    switch_l = []
    split_l = []
    
    for idx in range(len(word)+1):
        split_l.append((word[:idx], word[idx:]))
    
    for l,r in split_l:
        if len(r) > 1:
            switch_l.append(l + r[1] + r[0] + r[2:])
    
    return switch_l

# %%
switch_word_l = switch_letter(word="ocma",
                         verbose=True)

print(switch_word_l)
# Out:
# ['coma', 'omca', 'ocam']

# %% [markdown]
# Implementación de la función `replace_ letter`:
#
# Dada una palabra, por ejemplo "hola", debe retorna el conjunto de posibles palabras generadas al reemplazar cada caracter por el abecedario.
#
# `[('', 'hola'), ('h', 'ola'), ('ho', 'la'), ('hol', 'a'), ('hola', '')]`

# %%
def replace_letter(word, verbose=False):
    '''
    Input:
        word: the input string/word 
    Output:
        replaces: a list of all possible strings where we replaced one letter from the original word. 
    ''' 
    
    letters = 'abcdefghijklmnñopqrstuvwxyz'
    
    replace_l = []
    split_l = []
    
    for idx in range(len(word)+1):
        split_l.append((word[:idx], word[idx:]))
        
    for w in letters:
        for l,r in split_l:
            if r:
                new_word = l + w + r[1:]
                if new_word != word:
                    replace_l.append(new_word)
                    
    replace_l = sorted(replace_l)
    
    return replace_l

# %%
replace_l = replace_letter(word='cpma',
                              verbose=True)

print(replace_l)
# Out:
# ['apma', 'bpma', 'cama', 'cbma', 'ccma', 'cdma', 'cema', 'cfma', 'cgma', 'chma', 'cima', 'cjma', 'ckma', 'clma', 'cmma', 'cnma', 'coma', 'cpaa', 'cpba', 'cpca', 'cpda', 'cpea', 'cpfa', 'cpga', 'cpha', 'cpia', 'cpja', 'cpka', 'cpla', 'cpmb', 'cpmc', 'cpmd', 'cpme', 'cpmf', 'cpmg', 'cpmh', 'cpmi', 'cpmj', 'cpmk', 'cpml', 'cpmm', 'cpmn', 'cpmo', 'cpmp', 'cpmq', 'cpmr', 'cpms', 'cpmt', 'cpmu', 'cpmv', 'cpmw', 'cpmx', 'cpmy', 'cpmz', 'cpmñ', 'cpna', 'cpoa', 'cppa', 'cpqa', 'cpra', 'cpsa', 'cpta', 'cpua', 'cpva', 'cpwa', 'cpxa', 'cpya', 'cpza', 'cpña', 'cqma', 'crma', 'csma', 'ctma', 'cuma', 'cvma', 'cwma', 'cxma', 'cyma', 'czma', 'cñma', 'dpma', 'epma', 'fpma', 'gpma', 'hpma', 'ipma', 'jpma', 'kpma', 'lpma', 'mpma', 'npma', 'opma', 'ppma', 'qpma', 'rpma', 'spma', 'tpma', 'upma', 'vpma', 'wpma', 'xpma', 'ypma', 'zpma', 'ñpma']

# %% [markdown]
# Implementación de la función `insert_ letter`:
#
# Dada una palabra, por ejemplo "hola", debe retorna el conjunto de posibles palabras generadas al insertar cada caracter del abecedario.
#
# `[('', 'hola'), ('h', 'ola'), ('ho', 'la'), ('hol', 'a'), ('hola', '')]`

# %%
def insert_letter(word, verbose=False):
    '''
    Input:
        word: the input string/word 
    Output:
        inserts: a set of all possible strings with one new letter inserted at every offset
    ''' 
    letters = 'abcdefghijklmnñopqrstuvwxyz'
    insert_l = []
    split_l = []
    
    for idx in range(len(word)+1):
        split_l.append((word[:idx], word[idx:]))
        
    for w in letters:
        for l,r in split_l:
            insert_l.append(l + w + r)
    
    return insert_l

# %%
insert_l = insert_letter('ola', True)
print(f"Number of strings output by insert_letter('at') is {len(insert_l)}")
print(insert_l)
# Out:
# Number of strings output by insert_letter('at') is 108
# ['aola', 'oala', 'olaa', 'olaa', 'bola', 'obla', 'olba', 'olab', 'cola', 'ocla', 'olca', 'olac', 'dola', 'odla', 'olda', 'olad', 'eola', 'oela', 'olea', 'olae', 'fola', 'ofla', 'olfa', 'olaf', 'gola', 'ogla', 'olga', 'olag', 'hola', 'ohla', 'olha', 'olah', 'iola', 'oila', 'olia', 'olai', 'jola', 'ojla', 'olja', 'olaj', 'kola', 'okla', 'olka', 'olak', 'lola', 'olla', 'olla', 'olal', 'mola', 'omla', 'olma', 'olam', 'nola', 'onla', 'olna', 'olan', 'ñola', 'oñla', 'olña', 'olañ', 'oola', 'oola', 'oloa', 'olao', 'pola', 'opla', 'olpa', 'olap', 'qola', 'oqla', 'olqa', 'olaq', 'rola', 'orla', 'olra', 'olar', 'sola', 'osla', 'olsa', 'olas', 'tola', 'otla', 'olta', 'olat', 'uola', 'oula', 'olua', 'olau', 'vola', 'ovla', 'olva', 'olav', 'wola', 'owla', 'olwa', 'olaw', 'xola', 'oxla', 'olxa', 'olax', 'yola', 'oyla', 'olya', 'olay', 'zola', 'ozla', 'olza', 'olaz']

# %% [markdown]
# Hasta este punto, ya tenemos todas las palabras con un caracter modificado. Ahora, crearemos una función `edit_one_letter`, la cual recibe una palabra como entrada y retorna todas las posibles combinaciones entre las operaciónes de reemplazar, insertar, eliminar y combinar:

# %%
def edit_one_letter(word, allow_switches = True):
    """
    Input:
        word: the string/word for which we will generate all possible wordsthat are one edit away.
    Output:
        edit_one_set: a set of words with one possible edit. Please return a set. and not a list.
    """
    
    edit_one_set = set()
    
    edit_one_set = set(delete_letter(word)) | set (replace_letter(word)) | set (insert_letter(word)) | set(switch_letter(word))
    
    return set(edit_one_set)

# %%
tmp_word = "tma"
tmp_edit_one_set = edit_one_letter(tmp_word)
# turn this into a list to sort it, in order to view it
tmp_edit_one_l = sorted(list(tmp_edit_one_set))

print(f"input word {tmp_word} \nedit_one_l \n{tmp_edit_one_l}\n")
print(f"The type of the returned object should be a set {type(tmp_edit_one_set)}")
print(f"Number of outputs from edit_one_letter('cama') is {len(edit_one_letter(tmp_word))}")
# Out:
# l, r: [('', 'tma'), ('t', 'ma'), ('tm', 'a'), ('tma', '')]
# input word tma
# edit_one_l
# ['ama', 'atma', 'bma', 'btma', 'cma', 'ctma', 'dma', 'dtma', 'ema', 'etma', 'fma', 'ftma', 'gma', 'gtma', 'hma', 'htma', 'ima', 'itma', 'jma', 'jtma', 'kma', 'ktma', 'lma', 'ltma', 'ma', 'mma', 'mta', 'mtma', 'nma', 'ntma', 'oma', 'otma', 'pma', 'ptma', 'qma', 'qtma', 'rma', 'rtma', 'sma', 'stma', 'ta', 'taa', 'tam', 'tama', 'tba', 'tbma', 'tca', 'tcma', 'tda', 'tdma', 'tea', 'tema', 'tfa', 'tfma', 'tga', 'tgma', 'tha', 'thma', 'tia', 'tima', 'tja', 'tjma', 'tka', 'tkma', 'tla', 'tlma', 'tm', 'tmaa', 'tmab', 'tmac', 'tmad', 'tmae', 'tmaf', 'tmag', 'tmah', 'tmai', 'tmaj', 'tmak', 'tmal', 'tmam', 'tman', 'tmao', 'tmap', 'tmaq', 'tmar', 'tmas', 'tmat', 'tmau', 'tmav', 'tmaw', 'tmax', 'tmay', 'tmaz', 'tmañ', 'tmb', 'tmba', 'tmc', 'tmca', 'tmd', 'tmda', 'tme', 'tmea', 'tmf', 'tmfa', 'tmg', 'tmga', 'tmh', 'tmha', 'tmi', 'tmia', 'tmj', 'tmja', 'tmk', 'tmka', 'tml', 'tmla', 'tmm', 'tmma', 'tmn', 'tmna', 'tmo', 'tmoa', 'tmp', 'tmpa', 'tmq', 'tmqa', 'tmr', 'tmra', 'tms', 'tmsa', 'tmt', 'tmta', 'tmu', 'tmua', 'tmv', 'tmva', 'tmw', 'tmwa', 'tmx', 'tmxa', 'tmy', 'tmya', 'tmz', 'tmza', 'tmñ', 'tmña', 'tna', 'tnma', 'toa', 'toma', 'tpa', 'tpma', 'tqa', 'tqma', 'tra', 'trma', 'tsa', 'tsma', 'tta', 'ttma', 'tua', 'tuma', 'tva', 'tvma', 'twa', 'twma', 'txa', 'txma', 'tya', 'tyma', 'tza', 'tzma', 'tña', 'tñma', 'uma', 'utma', 'vma', 'vtma', 'wma', 'wtma', 'xma', 'xtma', 'yma', 'ytma', 'zma', 'ztma', 'ñma', 'ñtma']
#
# The type of the returned object should be a set <class 'set'>
# l, r: [('', 'tma'), ('t', 'ma'), ('tm', 'a'), ('tma', '')]
# Number of outputs from edit_one_letter('cama') is 188

# %% [markdown]
# #### Palabras sugeridas

# %%
def get_corrections(word, probs, vocab, n=3, verbose = False):
    '''
    Input: 
        word: a user entered string to check for suggestions
        probs: a dictionary that maps each word to its probability in the corpus
        vocab: a set containing all the vocabulary
        n: number of possible word corrections you want returned in the dictionary
    Output: 
        n_best: a list of tuples with the most probable n corrected words and their probabilities.
    '''
    
    suggestions = []
    n_best = []
    suggestion_probs = {}
    
    if word in vocab:
        return [(word, probs[word])]
    
    suggestions = edit_one_letter(word)
    
    if suggestions:
        for w in suggestions:
            if w in vocab:
                suggestion_probs[w] = probs[w]
            else:
                suggestion_probs[w] = 0
    else:
        return [(word, 1)]
    
    sorted_suggestion_probs = sorted(suggestion_probs.items(), key=lambda kv: kv[1], reverse=True)
    
    for i in range(n):
        sugg_prob = sorted_suggestion_probs[i][1]
        if sugg_prob != 0:
            n_best.append((sorted_suggestion_probs[i][0], sorted_suggestion_probs[i][1]))
            
    print(sorted_suggestion_probs)
    
    if verbose: print("entered word = ", word, "\nsuggestions = ", suggestions)

    return n_best

# %%
# Test your implementation - feel free to try other words in my word
my_word = 'ler' 
tmp_corrections = get_corrections(my_word, probs, vocab, 20, verbose=False) # keep verbose=True
for i, word_prob in enumerate(tmp_corrections):
    print(f"word {i}: {word_prob[0]}, probability {word_prob[1]:.6f}")

# CODE REVIEW COMMENT: using "tmp_corrections" insteads of "cors". "cors" is not defined
print(f"data type of corrections {type(tmp_corrections)}")
# Out:
# [('le', 0.0018375061250204168), ('ser', 0.0013183377277924259), ('les', 0.00043750145833819446), ('ver', 0.0002566675222250741), ('ley', 0.00020416734722449075), ('per', 4.083346944489815e-05), ('leer', 2.333341111137037e-05), ('oler', 1.1666705555685186e-05), ('lei', 5.833352777842593e-06), ('lee', 5.833352777842593e-06), ('lel', 0), ('leri', 0), ('llr', 0), ('fer', 0), ('vler', 0), ('len', 0), ('lvr', 0), ('lerñ', 0), ('lwer', 0), ('mer', 0), ('leru', 0), ('lerl', 0), ('lier', 0), ('sler', 0), ('wer', 0), ('lerd', 0), ('lerm', 0), ('